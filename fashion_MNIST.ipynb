# %% [markdown]
# <a href="https://colab.research.google.com/github/Akash21-akki/Deep-Learning-Models/blob/main/fashion_MNIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
(x_train_images, y_train_labels), (x_test_images, y_test_labels) = tf.keras.datasets.fashion_mnist.load_data()
assert x_train_images.shape == (60000, 28, 28)
assert x_test_images.shape == (10000, 28, 28)
assert y_train_labels.shape == (60000,)
assert y_test_labels.shape == (10000,)
# Out:
# ...
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
plt.imshow(x_train_images[0])

# %%
# With Scaled
(x_train_images, y_train_labels), (x_test_images, y_test_labels) = tf.keras.datasets.fashion_mnist.load_data()
assert x_train_images.shape == (60000, 28, 28)
assert x_test_images.shape == (10000, 28, 28)
assert y_train_labels.shape == (60000,)
assert y_test_labels.shape == (10000,)
x_train_images.flatten
x_test_images.flatten
input_shape=(28,28)
# x_train_flat = x_train.reshape(len(x_train),28*28)
# x_test_flat = x_test.reshape(len(x_test),28*28)
x_train = x_train_images / 255;
x_test = x_test_images / 255;
flatten = keras.layers.Flatten();

model = keras.Sequential([
    keras.layers.Input(shape=input_shape),
    flatten,
    keras.layers.Dense(10,activation="sigmoid"),
    # keras.layers.Dense(10, activation='softmax')
    # keras.layers.Dense(10, activation='tanh')
    # keras.layers.Dense(10, activation='relu')
    ])

model.compile(optimizer="adam",loss='sparse_categorical_crossentropy',metrics=['Accuracy'])
model.fit(x_train,y_train_labels,epochs=5,verbose=1)
model.evaluate(x_test,y_test_labels,verbose=False)
model.predict(x_test[1:2])
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - Accuracy: 0.7989 - loss: 0.5976
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - Accuracy: 0.8419 - loss: 0.4613
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - Accuracy: 0.8501 - loss: 0.4352
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - Accuracy: 0.8539 - loss: 0.4223
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - Accuracy: 0.8573 - loss: 0.4128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# array([[1.8442439e-02, 7.9967822e-06, 9.8020160e-01, 6.7090004e-05,
#         4.0297499e-01, 9.0370691e-13, 5.6605166e-01, 2.9502482e-17,
#         2.4411413e-03, 1.1939169e-13]], dtype=float32)

# %%
# With Scaled
(x_train_images, y_train_labels), (x_test_images, y_test_labels) = tf.keras.datasets.fashion_mnist.load_data()
assert x_train_images.shape == (60000, 28, 28)
assert x_test_images.shape == (10000, 28, 28)
assert y_train_labels.shape == (60000,)
assert y_test_labels.shape == (10000,)
x_train_images.flatten
x_test_images.flatten
input_shape=(28,28)
# x_train_flat = x_train.reshape(len(x_train),28*28)
# x_test_flat = x_test.reshape(len(x_test),28*28)
x_train = x_train_images / 255;
x_test = x_test_images / 255;
flatten = keras.layers.Flatten();

model = keras.Sequential([
    keras.layers.Input(shape=input_shape),
    flatten,
    keras.layers.Dense(10,activation="sigmoid"),
    # keras.layers.Dense(10, activation='softmax')
    # keras.layers.Dense(10, activation='tanh')
    # keras.layers.Dense(10, activation='relu')
    ])

model.compile(optimizer="adam",loss='sparse_categorical_crossentropy',metrics=['Accuracy'])
# model.compile(optimizer="adam",loss='mean_absolute_error',metrics=['Accuracy'])
# model.compile(optimizer="adam",loss='mean_squared_error',metrics=['Accuracy'])
# model.compile(optimizer="adam",loss='binary_cross_entrophy',metrics=['Accuracy'])
model.fit(x_train,y_train_labels,epochs=5,verbose=1)
model.evaluate(x_test,y_test_labels,verbose=False)
model.predict(x_train[1:2])
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - Accuracy: 0.8002 - loss: 0.5968
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - Accuracy: 0.8437 - loss: 0.4615
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - Accuracy: 0.8491 - loss: 0.4362
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - Accuracy: 0.8533 - loss: 0.4226
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - Accuracy: 0.8567 - loss: 0.4145
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# array([[9.9788457e-01, 3.7503203e-06, 6.4848071e-01, 6.8537518e-03,
#         9.2525537e-05, 3.1866703e-17, 4.0980279e-01, 7.1913287e-18,
#         4.8084508e-04, 7.4544280e-11]], dtype=float32)

# %%
plt.imshow(x_test[1])

# %%
print(y_test_labels)
# Out:
# [9 2 1 ... 8 1 5]

# %%
def label_image():
    label_map = {
        0: "T-shirt/top",
        1: "Trouser",
        2: "Pullover",
        3: "Dress",
        4: "Coat",
        5: "Sandal",
        6: "Shirt",
        7: "Sneaker",
        8: "Bag",
        9: "Ankle boot"
    }

    image_map = {v: k for k, v in label_map.items()}
    return(image_map[input('?')])

print(label_image())
# Out:
# ?Bag
# 8

# %%
from fastapi import FastAPI, UploadFile, File
import tensorflow as tf
import numpy as np
from PIL import Image, ImageOps
import io

app = FastAPI()

# !ls

model.save("mnist_model.keras")

model = tf.keras.models.load_model("mnist_model.keras")

# Model Load
# model = tf.keras.models.load_model("mnist_model.keras")

def preprocess_image(data):
    # Image open and convert to grayscale
    img = Image.open(io.BytesIO(data)).convert('L')

    # MNIST logic: model expects black background and white digit
    img = ImageOps.invert(img)

    img = img.resize((28, 28))
    img_array = np.array(img) / 255.0
    img_array = img_array.reshape(1, 28, 28)
    return img_array

@app.post("/predict")
async def predict(file: UploadFile = File(...)):
    try:
        data = await file.read()
        img = preprocess_image(data)

        prediction = model.predict(img)
        result = np.argmax(prediction)
        confidence = float(np.max(prediction))

        return {
            "status": "success",
            "prediction": int(result),
            "confidence": f"{confidence:.2%}"
        }
    except Exception as e:
        return {"status": "error", "message": str(e)}
# Out:
# sample_data

# %%
! pip install pyngrok

# %%
import nest_asyncio
import uvicorn
import asyncio
from pyngrok import ngrok

# 1. Nesting allow karein
nest_asyncio.apply()

# 2. Ngrok Setup
ngrok.kill()
auth_token = "3CbnzzimbwF2d0Ixu5r0XTUw4qK_5wQmeBStRdFgyGrwbnrCh"
ngrok.set_auth_token(auth_token)

# Tunnel create
public_url = ngrok.connect(8000)
print(f"Public URL: {public_url}")
print(f"Docs URL: {public_url}/docs")

# 3. Server run karne ka alternative tareeka (Threaded)
import threading

def run_api():
    uvicorn.run(app, host="127.0.0.1", port=8000, log_level="info")

# Thread start
threading.Thread(target=run_api, daemon=True).start()
# Out:
# Public URL: NgrokTunnel: "https://squint-barcode-motion.ngrok-free.dev" -> "http://localhost:8000"
# Docs URL: NgrokTunnel: "https://squint-barcode-motion.ngrok-free.dev" -> "http://localhost:8000"/docs
